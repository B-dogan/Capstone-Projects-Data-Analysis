# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from scipy import stats

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_columns', None)

# %%
df_origin = pd.read_csv("filled_scout.csv")
df = df_origin.copy()
df.head()
# Out:
#   make_model body_type    price       km  prev_owner body_color paint_type  \
# 0    Audi A1    Sedans  15770.0  56013.0         2.0      Black   Metallic
# 1    Audi A1    Sedans  14500.0  80000.0         1.0        Red   Metallic
# 2    Audi A1    Sedans  14640.0  83450.0         1.0      Black   Metallic
# 3    Audi A1    Sedans  14500.0  73000.0         1.0      Brown   Metallic
# 4    Audi A1    Sedans  16790.0  16200.0         1.0      Black   Metallic
#
#    number_of_doors  number_of_seats gearing_type  Cylinders drive_chain  \
# 0              5.0              5.0    Automatic        3.0       front
# 1              3.0              4.0    Automatic        4.0       front
# 2              4.0              4.0    Automatic        4.0       front
# 3              3.0              4.0    Automatic        3.0       front
# 4              5.0              5.0    Automatic        3.0       front
#
#       Fuel  co2_emission                                comfort_convenience  \
# 0   Diesel          99.0  Air conditioning,Armrest,Automatic climate con...
# 1  Benzine         129.0  Air conditioning,Automatic climate control,Hil...
# 2   Diesel          99.0  Air conditioning,Cruise control,Electrical sid...
# 3   Diesel          99.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4   Diesel         109.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  entertainment_media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
#
#                                      safety_security  Gears  age  hp_kw Type_  \
# 0  ABS,Central door lock,Daytime running lights,D...    5.0  3.0   66.0  Used
# 1  ABS,Central door lock,Central door lock with r...    7.0  2.0  141.0  Used
# 2  ABS,Central door lock,Daytime running lights,D...    5.0  3.0   85.0  Used
# 3  ABS,Alarm system,Central door lock with remote...    6.0  3.0   66.0  Used
# 4  ABS,Central door lock,Driver-side airbag,Elect...    5.0  3.0   66.0  Used
#
#   upholstery_type upholstery_color  displacement_cc  Consumption_comb  \
# 0           Cloth            Black           1422.0               3.8
# 1           Cloth             Grey           1798.0               5.6
# 2           Cloth            Black           1598.0               3.8
# 3           Cloth            Black           1422.0               3.8
# 4           Cloth            Black           1422.0               4.1
#
#    Consumption_city  Consumption_country insp_new
# 0               3.5                  3.5      Yes
# 1               4.7                  4.7       No
# 2               3.4                  3.4       No
# 3               3.5                  3.5       No
# 4               3.8                  3.8      Yes

# %%
df.sample(8)
# Out:
#            make_model      body_type    price            km  prev_owner  \
# 3707          Audi A3         Sedans  21900.0  12103.000000         1.0
# 15778  Renault Espace            Van  34200.0      1.000000         1.0
# 12788   Opel Insignia  Station wagon  35990.0   4900.000000         1.0
# 1589          Audi A1        Compact  23777.0   9000.000000         1.0
# 2421          Audi A1         Sedans  18950.0   1523.657526         1.0
# 13213    Renault Clio        Compact  13500.0  70760.000000         1.0
# 4073          Audi A3         Sedans  19490.0  44200.000000         1.0
# 2009          Audi A1         Sedans  27200.0    100.000000         1.0
#
#       body_color paint_type  number_of_doors  number_of_seats gearing_type  \
# 3707       White  Uni/basic              4.0              5.0    Automatic
# 15778      White   Metallic              5.0              7.0    Automatic
# 12788      White   Metallic              5.0              5.0       Manual
# 1589        Grey   Metallic              4.0              5.0    Automatic
# 2421       White   Metallic              5.0              5.0       Manual
# 13213       Grey   Metallic              5.0              5.0    Automatic
# 4073       Black   Metallic              5.0              5.0       Manual
# 2009       White   Metallic              5.0              5.0    Automatic
#
#        Cylinders drive_chain     Fuel  co2_emission  \
# 3707         4.0       front   Diesel         105.0
# 15778        4.0         4WD   Diesel         120.0
# 12788        4.0       front  Benzine         139.0
# 1589         3.0       front  Benzine         102.0
# 2421         3.0       front  Benzine         104.0
# 13213        4.0       front  Benzine         120.0
# 4073         4.0       front   Diesel         108.0
# 2009         3.0       front  Benzine         108.0
#
#                                      comfort_convenience  \
# 3707   Air conditioning,Armrest,Electrical side mirro...
# 15778  Air conditioning,Automatic climate control,Cru...
# 12788  Air conditioning,Armrest,Automatic climate con...
# 1589   Air conditioning,Armrest,Automatic climate con...
# 2421                      Air conditioning,Power windows
# 13213  Air conditioning,Cruise control,Electrical sid...
# 4073   Air conditioning,Automatic climate control,Cru...
# 2009   Air conditioning,Automatic climate control,Lea...
#
#                                      entertainment_media  \
# 3707            Bluetooth,Hands-free equipment,MP3,Radio
# 15778                                          Radio,USB
# 12788  Bluetooth,Digital radio,Hands-free equipment,O...
# 1589                                        Sound system
# 2421                                               Radio
# 13213  Bluetooth,Hands-free equipment,On-board comput...
# 4073   Bluetooth,CD player,Hands-free equipment,On-bo...
# 2009        Bluetooth,Hands-free equipment,MP3,Radio,USB
#
#                                                   Extras  \
# 3707           Alloy wheels,Sport seats,Sport suspension
# 15778                                       Alloy wheels
# 12788  Alloy wheels,Catalytic Converter,Roof rack,Spo...
# 1589                                        Alloy wheels
# 2421                                        Alloy wheels
# 13213                                       Alloy wheels
# 4073                              Alloy wheels,Roof rack
# 2009                                        Alloy wheels
#
#                                          safety_security  Gears  age  hp_kw  \
# 3707   ABS,Central door lock,Daytime running lights,D...    7.0  1.0   85.0
# 15778              ABS,Isofix,Power steering,Side airbag    6.0  1.0  118.0
# 12788  ABS,Central door lock,Daytime running lights,D...    6.0  0.0  121.0
# 1589   ABS,Driver-side airbag,Electronic stability co...    5.0  1.0   70.0
# 2421   ABS,Central door lock,Driver-side airbag,Elect...    5.0  0.0   70.0
# 13213  ABS,Central door lock,Daytime running lights,D...    6.0  3.0   87.0
# 4073   ABS,Central door lock,Daytime running lights,E...    6.0  2.0   85.0
# 2009   ABS,Central door lock,Daytime running lights,D...    7.0  0.0   85.0
#
#                 Type_ upholstery_type upholstery_color  displacement_cc  \
# 3707   Employee's car           Cloth            Other           1598.0
# 15778  Employee's car    Full leather            Black           1598.0
# 12788   Demonstration           Cloth            Black           1490.0
# 1589    Demonstration           Cloth            Black            999.0
# 2421              New           Cloth            Black            999.0
# 13213            Used           Cloth             Grey           1197.0
# 4073             Used    Full leather            Black           1598.0
# 2009   Pre-registered           Cloth            Other            999.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 3707                4.0               3.8                  3.8      Yes
# 15778               4.7               4.4                  4.4      Yes
# 12788               6.1               5.2                  5.2      Yes
# 1589                4.4               3.8                  3.8      Yes
# 2421                4.6               3.9                  3.9      Yes
# 13213               5.4               4.5                  4.5       No
# 4073                4.0               3.7                  3.7       No
# 2009                4.8               4.2                  4.2      Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15919 non-null  object
#  1   body_type            15919 non-null  object
#  2   price                15919 non-null  float64
#  3   km                   15919 non-null  float64
#  4   prev_owner           15919 non-null  float64
#  5   body_color           15919 non-null  object
#  6   paint_type           15919 non-null  object
#  7   number_of_doors      15919 non-null  float64
#  8   number_of_seats      15919 non-null  float64
#  9   gearing_type         15919 non-null  object
#  10  Cylinders            15919 non-null  float64
#  11  drive_chain          15919 non-null  object
#  12  Fuel                 15919 non-null  object
#  13  co2_emission         15919 non-null  float64
#  14  comfort_convenience  15919 non-null  object
#  15  entertainment_media  15919 non-null  object
#  16  Extras               15919 non-null  object
#  17  safety_security      15919 non-null  object
#  18  Gears                15919 non-null  float64
#  19  age                  15919 non-null  float64
#  20  hp_kw                15919 non-null  float64
#  21  Type_                15919 non-null  object
#  22  upholstery_type      15919 non-null  object
#  23  upholstery_color     15919 non-null  object
#  24  displacement_cc      15919 non-null  float64
#  25  Consumption_comb     15919 non-null  float64
#  26  Consumption_city     15919 non-null  float64
#  27  Consumption_country  15919 non-null  float64
#  28  insp_new             15919 non-null  object
# dtypes: float64(14), object(15)
# memory usage: 3.5+ MB

# %%
df.shape
# Out:
# (15919, 29)

# %%
## df.select_dtypes(include="number")  # bunu yazarak alabiliriz ; Ama NUMERIC OLMASINA RAĞMEN KATEGORİK OLAN SÜTUNLAR VAR
                                        # NR.OF.DOORS , AGE VS

# %%
def grab_col_names(dataframe,categ_th=13,cardi_th=25):        # threshold:eşik
    """
    Veri setindeki kategorik, numerik ve kategorik fakat kardinal değişkenlerin isimlerini verir.
    not : Kategorik değişkenlerin içerisine numeric görünümlü kategorik değişkenler de dahildir.

    Parameters
    ----------
    dataframe: dataframe
        değişken isimleri alınmak istenen dataframe'dir.
    cat_th: int, float
        numerik fakat kategorik olan değişkenler için sınıf eşik değeri
    car_th: int, float
        kategorik fakat kardinal değişkenler için sınıf eşik değeri

    Returns
    -------
    categ_cols: list
            Kategorik değişken listesi
    num_cols: list
            Numerik değişken listesi
    categ_but_cardi: list
            Kategorik görünümlü kardinal değişken listesi

    Notes
    ------
    categ_cols + num_cols + categ_but_cardi = toplam değişken sayısı
    num_but_categ; categ_cols'un içerisinde."""
    
    # categ_cols , categ_but_cardi
    categ_cols = [col for col in df.columns if  str(df[col].dtypes) in ["category","object","bool"]]
    num_but_categ = [col for col in df.columns if df[col].nunique() < categ_th  and str(df[col].dtypes) in ["int64","float64"]]
    categ_but_cardi = [col for col in df.columns if df[col].nunique() > cardi_th and  str(df[col].dtypes) in ["category","object"]]
    
    
    categ_cols =  categ_cols  +  num_but_categ
    categ_cols = [col for col in categ_cols if col not in categ_but_cardi]   ### cat_but_cardi'nin içinde olmayanları al diyoruz yani.
    
    
    
    # numeric:
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in num_but_categ]
    
    
    # rapor
    
    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f'categ_cols: {len(categ_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'categ_but_cardi: {len(categ_but_cardi)}')
    print(f'num_but_cat: {len(num_but_categ)}')
    
    
    return categ_cols, num_cols, categ_but_cardi

# %%
cat_cols , num_cols,categ_but_car = grab_col_names(df)
# Out:
# Observations: 15919
# Variables: 29
# categ_cols: 17
# num_cols: 8
# categ_but_cardi: 4
# num_but_cat: 6

# %%
categ_but_car
# Out:
# ['comfort_convenience', 'entertainment_media', 'Extras', 'safety_security']

# %%
df["comfort_convenience"]
# Out:
# 0        Air conditioning,Armrest,Automatic climate con...
# 1        Air conditioning,Automatic climate control,Hil...
# 2        Air conditioning,Cruise control,Electrical sid...
# 3        Air suspension,Armrest,Auxiliary heating,Elect...
# 4        Air conditioning,Armrest,Automatic climate con...
#                                ...
# 15914    Air conditioning,Automatic climate control,Cru...
# 15915    Air conditioning,Automatic climate control,Cru...
# 15916    Air conditioning,Armrest,Automatic climate con...
# 15917    Air conditioning,Automatic climate control,Cru...
# 15918    Air conditioning,Automatic climate control,Cru...
# Name: comfort_convenience, Length: 15919, dtype: object

# %%
df["entertainment_media"]
# Out:
# 0        Bluetooth,Hands-free equipment,On-board comput...
# 1        Bluetooth,Hands-free equipment,On-board comput...
# 2                                    MP3,On-board computer
# 3        Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4        Bluetooth,CD player,Hands-free equipment,MP3,O...
#                                ...
# 15914    Bluetooth,Digital radio,Hands-free equipment,O...
# 15915    Bluetooth,Digital radio,Hands-free equipment,R...
# 15916    Bluetooth,Hands-free equipment,On-board comput...
# 15917                    Bluetooth,Digital radio,Radio,USB
# 15918                                                  USB
# Name: entertainment_media, Length: 15919, dtype: object

# %%
num_cols
# Out:
# ['price',
#  'km',
#  'co2_emission',
#  'hp_kw',
#  'displacement_cc',
#  'Consumption_comb',
#  'Consumption_city',
#  'Consumption_country']

# %%
q1 = df["km"].quantile(q=0.25)
q3 = df["km"].quantile(q=0.75)
iqr = q3 - q1

# %%
q1
# Out:
# 3300.0

# %%
q3
# Out:
# 47000.0

# %%
up = q3 + 1.5 * iqr
low = q1 - 1.5 * iqr

# %%
low,up
# Out:
# (-62250.0, 112550.0)

# %%
df["km"].min()  ## mesela km sütunumda alt tarafta outlier olamaz bu durumda.
# Out:
# 0.0

# %%
df["km"].max()  ## bu mesela bir extreme değer.
# Out:
# 317000.0

# %%
##

# %%
df[(df["km"] < low ) | (df["km"] > up)].sort_values(by="km")                             ## 715 tane outlier var gibi duruyor.
# Out:
#            make_model      body_type    price        km  prev_owner  \
# 4352          Audi A3         Sedans  16690.0  112700.0         1.0
# 3194          Audi A3         Sedans  14890.0  112750.0         1.0
# 10600   Opel Insignia         Sedans  15400.0  112789.0         1.0
# 11238   Opel Insignia  Station wagon  18479.0  112895.0         1.0
# 11026   Opel Insignia  Station wagon  12980.0  112936.0         1.0
# ...               ...            ...      ...       ...         ...
# 15277  Renault Espace            Van  14600.0  240000.0         1.0
# 6224       Opel Astra  Station wagon   9800.0  248000.0         1.0
# 5712       Opel Astra  Station wagon   6000.0  260000.0         1.0
# 3003          Audi A3         Sedans  14980.0  291800.0         1.0
# 9279       Opel Corsa         Sedans   8350.0  317000.0         1.0
#
#       body_color paint_type  number_of_doors  number_of_seats gearing_type  \
# 4352       Black   Metallic              4.0              5.0       Manual
# 3194        Blue   Metallic              4.0              5.0       Manual
# 10600      Black   Metallic              4.0              5.0    Automatic
# 11238      White   Metallic              5.0              5.0    Automatic
# 11026      Black   Metallic              4.0              5.0       Manual
# ...          ...        ...              ...              ...          ...
# 15277      White   Metallic              5.0              5.0    Automatic
# 6224       White   Metallic              4.0              4.0       Manual
# 5712      Silver   Metallic              5.0              5.0    Automatic
# 3003        Blue   Metallic              4.0              5.0       Manual
# 9279         Red   Metallic              3.0              5.0       Manual
#
#        Cylinders drive_chain     Fuel  co2_emission  \
# 4352         4.0       front   Diesel         107.0
# 3194         4.0       front   Diesel         106.0
# 10600        4.0       front   Diesel         147.0
# 11238        4.0       front   Diesel         146.0
# 11026        4.0       front   Diesel         135.0
# ...          ...         ...      ...           ...
# 15277        4.0       front   Diesel         120.0
# 6224         4.0       front   Diesel         120.0
# 5712         4.0       front   Diesel         119.0
# 3003         4.0         4WD   Diesel         125.0
# 9279         4.0       front  Benzine         136.0
#
#                                      comfort_convenience  \
# 4352   Air conditioning,Automatic climate control,Ele...
# 3194   Air conditioning,Armrest,Automatic climate con...
# 10600  Air conditioning,Automatic climate control,Pow...
# 11238  Air conditioning,Armrest,Automatic climate con...
# 11026  Air conditioning,Automatic climate control,Cru...
# ...                                                  ...
# 15277  Air conditioning,Automatic climate control,Cru...
# 6224   Air conditioning,Armrest,Electrical side mirro...
# 5712   Air conditioning,Automatic climate control,Cru...
# 3003   Air conditioning,Armrest,Automatic climate con...
# 9279          Air conditioning,Hill Holder,Power windows
#
#                                      entertainment_media  \
# 4352   Bluetooth,CD player,Hands-free equipment,On-bo...
# 3194    Bluetooth,Hands-free equipment,On-board computer
# 10600                                  On-board computer
# 11238  Bluetooth,CD player,Digital radio,Hands-free e...
# 11026              Bluetooth,CD player,On-board computer
# ...                                                  ...
# 15277                                       Sound system
# 6224   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 5712   Bluetooth,Hands-free equipment,On-board comput...
# 3003   Bluetooth,CD player,Hands-free equipment,On-bo...
# 9279                                   On-board computer
#
#                                                   Extras  \
# 4352   Alloy wheels,Sport package,Sport seats,Trailer...
# 3194           Alloy wheels,Sport seats,Sport suspension
# 10600                                       Alloy wheels
# 11238               Alloy wheels,Roof rack,Shift paddles
# 11026   Alloy wheels,Roof rack,Sport seats,Trailer hitch
# ...                                                  ...
# 15277                                       Alloy wheels
# 6224                                        Touch screen
# 5712   Alloy wheels,Roof rack,Touch screen,Trailer hi...
# 3003   Alloy wheels,Sport package,Sport seats,Sport s...
# 9279                                        Alloy wheels
#
#                                          safety_security  Gears  age  hp_kw  \
# 4352   ABS,Central door lock,Central door lock with r...    6.0  2.0   81.0
# 3194   ABS,Central door lock,Driver-side airbag,Elect...    6.0  3.0   81.0
# 10600  ABS,Driver-side airbag,Electronic stability co...    6.0  2.0  125.0
# 11238  ABS,Adaptive Cruise Control,Adaptive headlight...    6.0  2.0  125.0
# 11026  ABS,Adaptive headlights,Central door lock,Dayt...    6.0  3.0  125.0
# ...                                                  ...    ...  ...    ...
# 15277  ABS,Central door lock with remote control,Driv...    6.0  2.0  118.0
# 6224   ABS,Alarm system,Central door lock,Electronic ...    6.0  3.0   81.0
# 5712   ABS,Central door lock,Central door lock with r...    6.0  3.0  100.0
# 3003   ABS,Adaptive headlights,Central door lock,Dayt...    6.0  3.0  110.0
# 9279   ABS,Central door lock with remote control,Dayt...    5.0  2.0   66.0
#
#                 Type_ upholstery_type upholstery_color  displacement_cc  \
# 4352             Used           Cloth            Black           1598.0
# 3194             Used           Cloth            Black           1598.0
# 10600  Employee's car           Cloth            Black           1956.0
# 11238            Used    Full leather            Black           1956.0
# 11026            Used    Full leather             Grey           1956.0
# ...               ...             ...              ...              ...
# 15277            Used    Full leather            Black           1598.0
# 6224             Used           Cloth            Black           1686.0
# 5712             Used           Cloth            Black           1598.0
# 3003             Used           Cloth            Black           1968.0
# 9279             Used           Cloth            Black           1398.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 4352                4.0               3.6                  3.6      Yes
# 3194                4.0               3.6                  3.6       No
# 10600               5.6               4.5                  4.5       No
# 11238               5.5               4.2                  4.2      Yes
# 11026               5.6               4.6                  4.6       No
# ...                 ...               ...                  ...      ...
# 15277               4.6               4.4                  4.4       No
# 6224                4.5               4.0                  4.0       No
# 5712                4.5               3.8                  3.8       No
# 3003                4.7               4.1                  4.1       No
# 9279                6.0               5.1                  5.1       No
#
# [715 rows x 29 columns]

# %%
df[(df["km"] < low ) | (df["km"] > up)].index
## ileride bunu kullanabiliriz .kulaklarından tuttuk getirdik.
# Out:
# Int64Index([   25,    34,    61,    63,    64,   328,   369,   397,   443,
#               465,
#             ...
#             15283, 15284, 15314, 15316, 15320, 15386, 15412, 15413, 15416,
#             15420],
#            dtype='int64', length=715)

# %%
df[(df["km"] < low ) | (df["km"] > up)].any(axis=None)

## any() -----> bu sorgu extreme değerleri getirecek bize herhangi bir extreme değer var mı diyoruz ; 
## axis = None ---> satır veya sütuna değil de hepsine bakmak istiyorum.
## bool döndüğüne dikkat edelim.
# Out:
# True

# %%
## yani ben ileride diyeceğim ki bu bana True döndürürse şunları yap False döndürürse şunları yap.

# %%
df[~((df["km"] < low ) | (df["km"] > up))]    ## extreme olmayanlar
# Out:
#            make_model body_type    price            km  prev_owner body_color  \
# 0             Audi A1    Sedans  15770.0  56013.000000         2.0      Black
# 1             Audi A1    Sedans  14500.0  80000.000000         1.0        Red
# 2             Audi A1    Sedans  14640.0  83450.000000         1.0      Black
# 3             Audi A1    Sedans  14500.0  73000.000000         1.0      Brown
# 4             Audi A1    Sedans  16790.0  16200.000000         1.0      Black
# ...               ...       ...      ...           ...         ...        ...
# 15914  Renault Espace       Van  39950.0   1434.035556         1.0       Grey
# 15915  Renault Espace       Van  39885.0   9900.000000         1.0       Grey
# 15916  Renault Espace       Van  39875.0     15.000000         1.0      White
# 15917  Renault Espace       Van  39700.0     10.000000         1.0       Grey
# 15918  Renault Espace       Van  40999.0   1434.035556         1.0       Grey
#
#       paint_type  number_of_doors  number_of_seats gearing_type  Cylinders  \
# 0       Metallic              5.0              5.0    Automatic        3.0
# 1       Metallic              3.0              4.0    Automatic        4.0
# 2       Metallic              4.0              4.0    Automatic        4.0
# 3       Metallic              3.0              4.0    Automatic        3.0
# 4       Metallic              5.0              5.0    Automatic        3.0
# ...          ...              ...              ...          ...        ...
# 15914   Metallic              5.0              5.0    Automatic        4.0
# 15915   Metallic              5.0              5.0    Automatic        4.0
# 15916   Metallic              5.0              7.0    Automatic        4.0
# 15917   Metallic              5.0              7.0    Automatic        4.0
# 15918   Metallic              5.0              5.0    Automatic        4.0
#
#       drive_chain     Fuel  co2_emission  \
# 0           front   Diesel          99.0
# 1           front  Benzine         129.0
# 2           front   Diesel          99.0
# 3           front   Diesel          99.0
# 4           front   Diesel         109.0
# ...           ...      ...           ...
# 15914       front   Diesel         139.0
# 15915       front  Benzine         168.0
# 15916       front   Diesel         139.0
# 15917       front   Diesel         139.0
# 15918         4WD  Benzine         153.0
#
#                                      comfort_convenience  \
# 0      Air conditioning,Armrest,Automatic climate con...
# 1      Air conditioning,Automatic climate control,Hil...
# 2      Air conditioning,Cruise control,Electrical sid...
# 3      Air suspension,Armrest,Auxiliary heating,Elect...
# 4      Air conditioning,Armrest,Automatic climate con...
# ...                                                  ...
# 15914  Air conditioning,Automatic climate control,Cru...
# 15915  Air conditioning,Automatic climate control,Cru...
# 15916  Air conditioning,Armrest,Automatic climate con...
# 15917  Air conditioning,Automatic climate control,Cru...
# 15918  Air conditioning,Automatic climate control,Cru...
#
#                                      entertainment_media  \
# 0      Bluetooth,Hands-free equipment,On-board comput...
# 1      Bluetooth,Hands-free equipment,On-board comput...
# 2                                  MP3,On-board computer
# 3      Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4      Bluetooth,CD player,Hands-free equipment,MP3,O...
# ...                                                  ...
# 15914  Bluetooth,Digital radio,Hands-free equipment,O...
# 15915  Bluetooth,Digital radio,Hands-free equipment,R...
# 15916  Bluetooth,Hands-free equipment,On-board comput...
# 15917                  Bluetooth,Digital radio,Radio,USB
# 15918                                                USB
#
#                                                   Extras  \
# 0         Alloy wheels,Catalytic Converter,Voice Control
# 1      Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                             Alloy wheels,Voice Control
# 3                 Alloy wheels,Sport seats,Voice Control
# 4      Alloy wheels,Sport package,Sport suspension,Vo...
# ...                                                  ...
# 15914                          Alloy wheels,Touch screen
# 15915            Alloy wheels,Touch screen,Voice Control
# 15916                                       Alloy wheels
# 15917                          Alloy wheels,Touch screen
# 15918                          Alloy wheels,Touch screen
#
#                                          safety_security  Gears  age  hp_kw  \
# 0      ABS,Central door lock,Daytime running lights,D...    5.0  3.0   66.0
# 1      ABS,Central door lock,Central door lock with r...    7.0  2.0  141.0
# 2      ABS,Central door lock,Daytime running lights,D...    5.0  3.0   85.0
# 3      ABS,Alarm system,Central door lock with remote...    6.0  3.0   66.0
# 4      ABS,Central door lock,Driver-side airbag,Elect...    5.0  3.0   66.0
# ...                                                  ...    ...  ...    ...
# 15914  ABS,Central door lock,Central door lock with r...    6.0  0.0  147.0
# 15915  ABS,Adaptive Cruise Control,Blind spot monitor...    7.0  0.0  165.0
# 15916  ABS,Adaptive Cruise Control,Blind spot monitor...    6.0  0.0  146.0
# 15917  ABS,Blind spot monitor,Driver-side airbag,Elec...    6.0  0.0  147.0
# 15918  ABS,Blind spot monitor,Daytime running lights,...    6.0  0.0  165.0
#
#                 Type_ upholstery_type upholstery_color  displacement_cc  \
# 0                Used           Cloth            Black           1422.0
# 1                Used           Cloth             Grey           1798.0
# 2                Used           Cloth            Black           1598.0
# 3                Used           Cloth            Black           1422.0
# 4                Used           Cloth            Black           1422.0
# ...               ...             ...              ...              ...
# 15914             New    Full leather            Black           1997.0
# 15915            Used           Cloth            Black           1798.0
# 15916  Pre-registered    Full leather            Black           1997.0
# 15917  Pre-registered    Part leather            Black           1997.0
# 15918   Demonstration    Full leather            Brown           1798.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 0                   3.8               3.5                  3.5      Yes
# 1                   5.6               4.7                  4.7       No
# 2                   3.8               3.4                  3.4       No
# 3                   3.8               3.5                  3.5       No
# 4                   4.1               3.8                  3.8      Yes
# ...                 ...               ...                  ...      ...
# 15914               5.3               4.7                  4.7      Yes
# 15915               7.4               6.3                  6.3      Yes
# 15916               5.3               4.7                  4.7      Yes
# 15917               5.3               4.7                  4.7      Yes
# 15918               6.8               5.7                  5.7      Yes
#
# [15204 rows x 29 columns]

# %%
df[~((df["km"] < low ) | (df["km"] > up))].any(axis=None)
# Out:
# True

# %%
df[(df["km"] < low)].any(axis=None)
# Out:
# False

# %%
def outlier_thresholds(dataframe, col_name, q1=0.25, q3=0.75):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

# %%
outlier_thresholds(df,"km")
# Out:
# (-62250.0, 112550.0)

# %%
outlier_thresholds(df,"km",q1=0.05,q3=0.95)
# Out:
# (-164839.99999999977, 274759.99999999965)

# %%
df["km"].median()
# Out:
# 20900.0

# %%
low,up = outlier_thresholds(df,"km")

# %%
df[(df["km"] < low ) | (df["km"] > up)].head(3)
# Out:
#    make_model body_type    price        km  prev_owner body_color paint_type  \
# 25    Audi A1    Sedans   8999.0  115000.0         1.0      White   Metallic
# 34    Audi A1    Sedans  11900.0  126000.0         1.0      White   Metallic
# 61    Audi A1   Compact   9950.0  118500.0         1.0      Black   Metallic
#
#     number_of_doors  number_of_seats gearing_type  Cylinders drive_chain  \
# 25              5.0              4.0       Manual        3.0       front
# 34              5.0              4.0       Manual        3.0       front
# 61              3.0              4.0       Manual        3.0       front
#
#        Fuel  co2_emission                                comfort_convenience  \
# 25  Benzine          97.0  Air conditioning,Electrical side mirrors,Leath...
# 34   Diesel          97.0  Air conditioning,Automatic climate control,Cru...
# 61  Benzine         102.0  Air conditioning,Armrest,Automatic climate con...
#
#                                   entertainment_media  \
# 25                                 Radio,Sound system
# 34  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 61  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                             Extras  \
# 25                       Alloy wheels,Winter tyres
# 34                                    Alloy wheels
# 61  Alloy wheels,Catalytic Converter,Voice Control
#
#                                       safety_security  Gears  age  hp_kw  \
# 25  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 34  ABS,Alarm system,Central door lock,Daytime run...    5.0  3.0   66.0
# 61  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
#
#    Type_ upholstery_type upholstery_color  displacement_cc  Consumption_comb  \
# 25  Used           Cloth            Black            999.0               4.2
# 34  Used           Cloth            Black           1422.0               3.7
# 61  Used           Cloth            Black            999.0               4.4
#
#     Consumption_city  Consumption_country insp_new
# 25               3.7                  3.7       No
# 34               3.4                  3.4       No
# 61               3.9                  3.9      Yes

# %%
df[(df["km"] < low ) | (df["km"] > up)].index
# Out:
# Int64Index([   25,    34,    61,    63,    64,   328,   369,   397,   443,
#               465,
#             ...
#             15283, 15284, 15314, 15316, 15320, 15386, 15412, 15413, 15416,
#             15420],
#            dtype='int64', length=715)

# %%
def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False

# %% [markdown]
# #### DİKKAT : outlier_thresholds FONKSİYONUNUN q1 ve q3 argümanlarını biçimlendirmek istersek eğer onları da check_outlier() fonksiyonuna parametre olarak girmemiz GEREKİR.

# %%
check_outlier(df, "km")
# Out:
# True

# %%
### check_outlier FONKSİYONUNUN BOOL RETURN  ETTİĞİNİ GÖZDEN KAÇIRMAYALIM.BUNU BİR KOD AKIŞI ESNASINDA KULLANABİLİRİZ

# %%
num_cols
# Out:
# ['price',
#  'km',
#  'co2_emission',
#  'hp_kw',
#  'displacement_cc',
#  'Consumption_comb',
#  'Consumption_city',
#  'Consumption_country']

# %%
# num_cols = [col for col in num_cols if col not in "unwanted feature"]

# %%
for col in num_cols:
    print(col,check_outlier(df,col))
# Out:
# price True
# km True
# co2_emission True
# hp_kw True
# displacement_cc True
# Consumption_comb True
# Consumption_city True
# Consumption_country True

# %%
## bütün  numeric sütunlarımda extreme değer varmış.

# %%
def grab_outliers(dataframe, col_name, index=False,q1 = 0.25,q3=0.75):
    low, up = outlier_thresholds(dataframe, col_name)
                                          
    if dataframe[((dataframe[col_name] < low) | (dataframe[col_name] > up))].shape[0] > 10:
        ## EĞER AYKIRI DEĞER 10'DAN BÜYÜKSE BİZE HEAD'İ VER
        print(dataframe[((dataframe[col_name] < low) | (dataframe[col_name] > up))].head())
    else:
        print(dataframe[((dataframe[col_name] < low) | (dataframe[col_name] > up))])

    if index:
        outlier_index = dataframe[((dataframe[col_name] < low) | (dataframe[col_name] > up))].index
        return outlier_index

# %% [markdown]
# ### grab_outliers bizim için bir analiz fonksiyonu ama index=True yaparak bize indexleri de return ettirebiliriz.

# %%
grab_outliers(df, "km")
# Out:
#    make_model body_type    price        km  prev_owner body_color paint_type  \
# 25    Audi A1    Sedans   8999.0  115000.0         1.0      White   Metallic
# 34    Audi A1    Sedans  11900.0  126000.0         1.0      White   Metallic
# 61    Audi A1   Compact   9950.0  118500.0         1.0      Black   Metallic
# 63    Audi A1    Sedans  10000.0  192000.0         1.0      Black   Metallic
# 64    Audi A1   Compact  10490.0  130000.0         1.0      White   Metallic
#
#     number_of_doors  number_of_seats gearing_type  Cylinders drive_chain  \
# 25              5.0              4.0       Manual        3.0       front
# 34              5.0              4.0       Manual        3.0       front
# 61              3.0              4.0       Manual        3.0       front
# 63              5.0              4.0       Manual        4.0       front
# 64              4.0              4.0       Manual        3.0       front
#
#        Fuel  co2_emission                                comfort_convenience  \
# 25  Benzine          97.0  Air conditioning,Electrical side mirrors,Leath...
# 34   Diesel          97.0  Air conditioning,Automatic climate control,Cru...
# 61  Benzine         102.0  Air conditioning,Armrest,Automatic climate con...
# 63   Diesel         102.0  Air conditioning,Armrest,Electrical side mirro...
# 64   Diesel         102.0  Air conditioning,Electrical side mirrors,Hill ...
#
#                                   entertainment_media  \
# 25                                 Radio,Sound system
# 34  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 61  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 63                                          MP3,Radio
# 64                                          CD player
#
#                                             Extras  \
# 25                       Alloy wheels,Winter tyres
# 34                                    Alloy wheels
# 61  Alloy wheels,Catalytic Converter,Voice Control
# 63                                    Alloy wheels
# 64                                    Alloy wheels
#
#                                       safety_security  Gears  age  hp_kw  \
# 25  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 34  ABS,Alarm system,Central door lock,Daytime run...    5.0  3.0   66.0
# 61  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 63  ABS,Central door lock,Central door lock with r...    5.0  3.0   85.0
# 64  ABS,Central door lock,Daytime running lights,D...    5.0  3.0   66.0
#
#    Type_ upholstery_type upholstery_color  displacement_cc  Consumption_comb  \
# 25  Used           Cloth            Black            999.0               4.2
# 34  Used           Cloth            Black           1422.0               3.7
# 61  Used           Cloth            Black            999.0               4.4
# 63  Used           Cloth            Black           1598.0               3.9
# 64  Used           Cloth            Black           1422.0               3.9
#
#     Consumption_city  Consumption_country insp_new
# 25               3.7                  3.7       No
# 34               3.4                  3.4       No
# 61               3.9                  3.9      Yes
# 63               3.4                  3.4      Yes
# 64               3.6                  3.6      Yes

# %%
grab_outliers(df, "km",index=True)
# Out:
#    make_model body_type    price        km  prev_owner body_color paint_type  \
# 25    Audi A1    Sedans   8999.0  115000.0         1.0      White   Metallic
# 34    Audi A1    Sedans  11900.0  126000.0         1.0      White   Metallic
# 61    Audi A1   Compact   9950.0  118500.0         1.0      Black   Metallic
# 63    Audi A1    Sedans  10000.0  192000.0         1.0      Black   Metallic
# 64    Audi A1   Compact  10490.0  130000.0         1.0      White   Metallic
#
#     number_of_doors  number_of_seats gearing_type  Cylinders drive_chain  \
# 25              5.0              4.0       Manual        3.0       front
# 34              5.0              4.0       Manual        3.0       front
# 61              3.0              4.0       Manual        3.0       front
# 63              5.0              4.0       Manual        4.0       front
# 64              4.0              4.0       Manual        3.0       front
#
#        Fuel  co2_emission                                comfort_convenience  \
# 25  Benzine          97.0  Air conditioning,Electrical side mirrors,Leath...
# 34   Diesel          97.0  Air conditioning,Automatic climate control,Cru...
# 61  Benzine         102.0  Air conditioning,Armrest,Automatic climate con...
# 63   Diesel         102.0  Air conditioning,Armrest,Electrical side mirro...
# 64   Diesel         102.0  Air conditioning,Electrical side mirrors,Hill ...
#
#                                   entertainment_media  \
# 25                                 Radio,Sound system
# 34  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 61  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 63                                          MP3,Radio
# 64                                          CD player
#
#                                             Extras  \
# 25                       Alloy wheels,Winter tyres
# 34                                    Alloy wheels
# 61  Alloy wheels,Catalytic Converter,Voice Control
# 63                                    Alloy wheels
# 64                                    Alloy wheels
#
#                                       safety_security  Gears  age  hp_kw  \
# 25  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 34  ABS,Alarm system,Central door lock,Daytime run...    5.0  3.0   66.0
# 61  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 63  ABS,Central door lock,Central door lock with r...    5.0  3.0   85.0
# 64  ABS,Central door lock,Daytime running lights,D...    5.0  3.0   66.0
#
#    Type_ upholstery_type upholstery_color  displacement_cc  Consumption_comb  \
# 25  Used           Cloth            Black            999.0               4.2
# 34  Used           Cloth            Black           1422.0               3.7
# 61  Used           Cloth            Black            999.0               4.4
# 63  Used           Cloth            Black           1598.0               3.9
# 64  Used           Cloth            Black           1422.0               3.9
#
#     Consumption_city  Consumption_country insp_new
# 25               3.7                  3.7       No
# 34               3.4                  3.4       No
# 61               3.9                  3.9      Yes
# 63               3.4                  3.4      Yes
# 64               3.6                  3.6      Yes
# Int64Index([   25,    34,    61,    63,    64,   328,   369,   397,   443,
#               465,
#             ...
#             15283, 15284, 15314, 15316, 15320, 15386, 15412, 15413, 15416,
#             15420],
#            dtype='int64', length=715)

# %%
km_index = grab_outliers(df, "km",index=True)
# Out:
#    make_model body_type    price        km  prev_owner body_color paint_type  \
# 25    Audi A1    Sedans   8999.0  115000.0         1.0      White   Metallic
# 34    Audi A1    Sedans  11900.0  126000.0         1.0      White   Metallic
# 61    Audi A1   Compact   9950.0  118500.0         1.0      Black   Metallic
# 63    Audi A1    Sedans  10000.0  192000.0         1.0      Black   Metallic
# 64    Audi A1   Compact  10490.0  130000.0         1.0      White   Metallic
#
#     number_of_doors  number_of_seats gearing_type  Cylinders drive_chain  \
# 25              5.0              4.0       Manual        3.0       front
# 34              5.0              4.0       Manual        3.0       front
# 61              3.0              4.0       Manual        3.0       front
# 63              5.0              4.0       Manual        4.0       front
# 64              4.0              4.0       Manual        3.0       front
#
#        Fuel  co2_emission                                comfort_convenience  \
# 25  Benzine          97.0  Air conditioning,Electrical side mirrors,Leath...
# 34   Diesel          97.0  Air conditioning,Automatic climate control,Cru...
# 61  Benzine         102.0  Air conditioning,Armrest,Automatic climate con...
# 63   Diesel         102.0  Air conditioning,Armrest,Electrical side mirro...
# 64   Diesel         102.0  Air conditioning,Electrical side mirrors,Hill ...
#
#                                   entertainment_media  \
# 25                                 Radio,Sound system
# 34  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 61  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 63                                          MP3,Radio
# 64                                          CD player
#
#                                             Extras  \
# 25                       Alloy wheels,Winter tyres
# 34                                    Alloy wheels
# 61  Alloy wheels,Catalytic Converter,Voice Control
# 63                                    Alloy wheels
# 64                                    Alloy wheels
#
#                                       safety_security  Gears  age  hp_kw  \
# 25  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 34  ABS,Alarm system,Central door lock,Daytime run...    5.0  3.0   66.0
# 61  ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 63  ABS,Central door lock,Central door lock with r...    5.0  3.0   85.0
# 64  ABS,Central door lock,Daytime running lights,D...    5.0  3.0   66.0
#
#    Type_ upholstery_type upholstery_color  displacement_cc  Consumption_comb  \
# 25  Used           Cloth            Black            999.0               4.2
# 34  Used           Cloth            Black           1422.0               3.7
# 61  Used           Cloth            Black            999.0               4.4
# 63  Used           Cloth            Black           1598.0               3.9
# 64  Used           Cloth            Black           1422.0               3.9
#
#     Consumption_city  Consumption_country insp_new
# 25               3.7                  3.7       No
# 34               3.4                  3.4       No
# 61               3.9                  3.9      Yes
# 63               3.4                  3.4      Yes
# 64               3.6                  3.6      Yes

# %%
km_index
# Out:
# Int64Index([   25,    34,    61,    63,    64,   328,   369,   397,   443,
#               465,
#             ...
#             15283, 15284, 15314, 15316, 15320, 15386, 15412, 15413, 15416,
#             15420],
#            dtype='int64', length=715)

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x=df["km"])
plt.show()

# %%
plt.figure()
sns.histplot(df["km"], bins = 25,kde = False);

# %% [markdown]
# #### evet benim feature'mda extreme değerler var outlier demiyoruz daha ! bu exteme değerler outlier olabilir mi onu kurcalayacağız?

# %%
df.loc[km_index]
# Out:
#            make_model    body_type    price        km  prev_owner body_color  \
# 25            Audi A1       Sedans   8999.0  115000.0         1.0      White
# 34            Audi A1       Sedans  11900.0  126000.0         1.0      White
# 61            Audi A1      Compact   9950.0  118500.0         1.0      Black
# 63            Audi A1       Sedans  10000.0  192000.0         1.0      Black
# 64            Audi A1      Compact  10490.0  130000.0         1.0      White
# ...               ...          ...      ...       ...         ...        ...
# 15386  Renault Espace          Van  16900.0  122000.0         1.0      Black
# 15412  Renault Espace          Van  19900.0  130000.0         1.0     Violet
# 15413  Renault Espace  Transporter  20900.0  140000.0         1.0      Black
# 15416  Renault Espace          Van  19800.0  130000.0         1.0      Beige
# 15420  Renault Espace  Transporter  17500.0  120000.0         1.0       Grey
#
#       paint_type  number_of_doors  number_of_seats    gearing_type  Cylinders  \
# 25      Metallic              5.0              4.0          Manual        3.0
# 34      Metallic              5.0              4.0          Manual        3.0
# 61      Metallic              3.0              4.0          Manual        3.0
# 63      Metallic              5.0              4.0          Manual        4.0
# 64      Metallic              4.0              4.0          Manual        3.0
# ...          ...              ...              ...             ...        ...
# 15386   Metallic              5.0              5.0  Semi-automatic        4.0
# 15412   Metallic              5.0              5.0  Semi-automatic        4.0
# 15413   Metallic              5.0              5.0  Semi-automatic        4.0
# 15416   Metallic              5.0              7.0  Semi-automatic        4.0
# 15420   Metallic              5.0              7.0  Semi-automatic        4.0
#
#       drive_chain     Fuel  co2_emission  \
# 25          front  Benzine          97.0
# 34          front   Diesel          97.0
# 61          front  Benzine         102.0
# 63          front   Diesel         102.0
# 64          front   Diesel         102.0
# ...           ...      ...           ...
# 15386       front   Diesel         120.0
# 15412       front   Diesel         120.0
# 15413       front   Diesel         120.0
# 15416       front   Diesel         120.0
# 15420       front   Diesel         120.0
#
#                                      comfort_convenience  \
# 25     Air conditioning,Electrical side mirrors,Leath...
# 34     Air conditioning,Automatic climate control,Cru...
# 61     Air conditioning,Armrest,Automatic climate con...
# 63     Air conditioning,Armrest,Electrical side mirro...
# 64     Air conditioning,Electrical side mirrors,Hill ...
# ...                                                  ...
# 15386  Air conditioning,Armrest,Automatic climate con...
# 15412  Air conditioning,Armrest,Automatic climate con...
# 15413  Air conditioning,Armrest,Automatic climate con...
# 15416  Air conditioning,Armrest,Automatic climate con...
# 15420  Air conditioning,Armrest,Automatic climate con...
#
#                                      entertainment_media  \
# 25                                    Radio,Sound system
# 34     Bluetooth,CD player,Hands-free equipment,MP3,O...
# 61     Bluetooth,CD player,Hands-free equipment,MP3,O...
# 63                                             MP3,Radio
# 64                                             CD player
# ...                                                  ...
# 15386  Bluetooth,Hands-free equipment,MP3,On-board co...
# 15412  Bluetooth,Hands-free equipment,Radio,Sound sys...
# 15413  Bluetooth,CD player,Hands-free equipment,On-bo...
# 15416  Bluetooth,CD player,Digital radio,Hands-free e...
# 15420  Bluetooth,Digital radio,Hands-free equipment,M...
#
#                                                   Extras  \
# 25                             Alloy wheels,Winter tyres
# 34                                          Alloy wheels
# 61        Alloy wheels,Catalytic Converter,Voice Control
# 63                                          Alloy wheels
# 64                                          Alloy wheels
# ...                                                  ...
# 15386            Alloy wheels,Touch screen,Voice Control
# 15412  Alloy wheels,Catalytic Converter,Shift paddles...
# 15413  Alloy wheels,Handicapped enabled,Shift paddles...
# 15416    Alloy wheels,Ski bag,Touch screen,Voice Control
# 15420            Alloy wheels,Touch screen,Voice Control
#
#                                          safety_security  Gears  age  hp_kw  \
# 25     ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 34     ABS,Alarm system,Central door lock,Daytime run...    5.0  3.0   66.0
# 61     ABS,Central door lock,Central door lock with r...    5.0  3.0   70.0
# 63     ABS,Central door lock,Central door lock with r...    5.0  3.0   85.0
# 64     ABS,Central door lock,Daytime running lights,D...    5.0  3.0   66.0
# ...                                                  ...    ...  ...    ...
# 15386  ABS,Central door lock,Central door lock with r...    6.0  3.0  118.0
# 15412  ABS,Adaptive Cruise Control,Adaptive headlight...    6.0  3.0  118.0
# 15413  ABS,Alarm system,Electronic stability control,...    6.0  3.0  118.0
# 15416  ABS,Alarm system,Central door lock with remote...    6.0  3.0  118.0
# 15420  ABS,Alarm system,Driver-side airbag,Electronic...    6.0  3.0  118.0
#
#       Type_ upholstery_type upholstery_color  displacement_cc  \
# 25     Used           Cloth            Black            999.0
# 34     Used           Cloth            Black           1422.0
# 61     Used           Cloth            Black            999.0
# 63     Used           Cloth            Black           1598.0
# 64     Used           Cloth            Black           1422.0
# ...     ...             ...              ...              ...
# 15386  Used    Full leather            Black           1598.0
# 15412  Used    Full leather            Brown           1598.0
# 15413  Used    Full leather            Brown           1598.0
# 15416  Used    Part leather             Grey           1598.0
# 15420  Used    Full leather            Brown           1598.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 25                  4.2               3.7                  3.7       No
# 34                  3.7               3.4                  3.4       No
# 61                  4.4               3.9                  3.9      Yes
# 63                  3.9               3.4                  3.4      Yes
# 64                  3.9               3.6                  3.6      Yes
# ...                 ...               ...                  ...      ...
# 15386               4.7               4.4                  4.4       No
# 15412               4.7               4.4                  4.4       No
# 15413               4.7               4.4                  4.4       No
# 15416               4.7               4.4                  4.4       No
# 15420               4.7               4.4                  4.4       No
#
# [715 rows x 29 columns]

# %%
# km -------> log'u alınabilir belki ?

# %%
df.loc[km_index,["age","price","Type_"]]
# Out:
#        age    price Type_
# 25     3.0   8999.0  Used
# 34     3.0  11900.0  Used
# 61     3.0   9950.0  Used
# 63     3.0  10000.0  Used
# 64     3.0  10490.0  Used
# ...    ...      ...   ...
# 15386  3.0  16900.0  Used
# 15412  3.0  19900.0  Used
# 15413  3.0  20900.0  Used
# 15416  3.0  19800.0  Used
# 15420  3.0  17500.0  Used
#
# [715 rows x 3 columns]

# %%
## mesela age'i 0 olanların km yanlış girilmiş olabilir !!!
# mesela abartarak söylersek ; her gün 150 km yapsa bir insan  1 yılda max 55k km yapar.

# %%
df.loc[km_index,["age","price","Type_","km","make_model"]].sort_values(by="age")
# Out:
#        age    price Type_        km      make_model
# 2901   0.0  15500.0  Used  127022.0         Audi A3
# 14592  1.0  10450.0  Used  113392.0    Renault Clio
# 4312   1.0  17500.0  Used  136000.0         Audi A3
# 4377   2.0  16900.0  Used  115000.0         Audi A3
# 4388   2.0  19797.0  Used  114550.0         Audi A3
# ...    ...      ...   ...       ...             ...
# 6001   3.0  11890.0  Used  133590.0      Opel Astra
# 6021   3.0  12490.0  Used  142684.0      Opel Astra
# 6033   3.0  11480.0  Used  124349.0      Opel Astra
# 6038   3.0  11250.0  Used  139000.0      Opel Astra
# 15420  3.0  17500.0  Used  120000.0  Renault Espace
#
# [715 rows x 5 columns]

# %%
df.loc[(df["age"]== 0) & (df["make_model"] == "Audi A3"),["km","price"]].sort_values(by="price")
# Out:
#                  km    price
# 2901  127022.000000  15500.0
# 4031   82400.000000  17990.0
# 4227       1.000000  18820.0
# 4198    2499.124803  18980.0
# 4045      10.000000  19078.0
# ...             ...      ...
# 3613       7.000000  38725.0
# 3591       7.000000  39575.0
# 3607     750.000000  41495.0
# 3590     700.000000  62900.0
# 3595      10.000000  63900.0
#
# [759 rows x 2 columns]

# %%
num_cols
# Out:
# ['price',
#  'km',
#  'co2_emission',
#  'hp_kw',
#  'displacement_cc',
#  'Consumption_comb',
#  'Consumption_city',
#  'Consumption_country']

# %% [markdown]
# ### displacement_cc

# %%
df["displacement_cc"]
# Out:
# 0        1422.0
# 1        1798.0
# 2        1598.0
# 3        1422.0
# 4        1422.0
#           ...
# 15914    1997.0
# 15915    1798.0
# 15916    1997.0
# 15917    1997.0
# 15918    1798.0
# Name: displacement_cc, Length: 15919, dtype: float64

# %%
df["displacement_cc"].sort_values()
# Out:
# 12790        1.0
# 14319        1.0
# 14315        1.0
# 12849        1.0
# 12848        1.0
#           ...
# 3599      2480.0
# 3649      2480.0
# 10771     2967.0
# 7169     15898.0
# 10932    16000.0
# Name: displacement_cc, Length: 15919, dtype: float64

# %%
outlier_thresholds(df,"displacement_cc")
# Out:
# (675.5, 2151.5)

# %%
df["displacement_cc"].min()              # belki bu 1000 cc olabilir adam yanlış anlamş olabilir atmaktansa düzeltelim.
# Out:
# 1.0

# %%
df["displacement_cc"].max()
# Out:
# 16000.0

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x = df["displacement_cc"])
# Out:
# <AxesSubplot:xlabel='displacement_cc'>

# %%
displacement_cc_index =   grab_outliers(df,"displacement_cc",index=True)
# Out:
#      make_model      body_type    price       km  prev_owner body_color  \
# 3587    Audi A3         Sedans  64900.0  35000.0         1.0       Grey
# 3590    Audi A3         Sedans  62900.0    700.0         1.0       Grey
# 3592    Audi A3         Sedans  56900.0   5200.0         1.0       Grey
# 3593    Audi A3         Sedans  58500.0  10000.0         1.0      White
# 3595    Audi A3  Station wagon  63900.0     10.0         1.0      Black
#
#      paint_type  number_of_doors  number_of_seats    gearing_type  Cylinders  \
# 3587   Metallic              5.0              5.0  Semi-automatic        5.0
# 3590   Metallic              5.0              5.0  Semi-automatic        5.0
# 3592   Metallic              5.0              5.0  Semi-automatic        5.0
# 3593   Metallic              5.0              5.0  Semi-automatic        5.0
# 3595   Metallic              5.0              5.0  Semi-automatic        5.0
#
#      drive_chain     Fuel  co2_emission  \
# 3587         4WD  Benzine         189.0
# 3590         4WD  Benzine         194.0
# 3592         4WD  Benzine         189.0
# 3593         4WD  Benzine         189.0
# 3595       front  Benzine         189.0
#
#                                     comfort_convenience  \
# 3587  Air conditioning,Seat ventilation,Split rear s...
# 3590  Air conditioning,Seat ventilation,Split rear s...
# 3592  Air conditioning,Air suspension,Armrest,Automa...
# 3593  Air conditioning,Seat ventilation,Split rear s...
# 3595  Air conditioning,Armrest,Automatic climate con...
#
#                                     entertainment_media  \
# 3587                                              Radio
# 3590                                    Bluetooth,Radio
# 3592  Bluetooth,CD player,Digital radio,Hands-free e...
# 3593                                              Radio
# 3595  Bluetooth,CD player,Digital radio,Hands-free e...
#
#                                                  Extras  \
# 3587                                       Alloy wheels
# 3590                                       Alloy wheels
# 3592  Alloy wheels,Shift paddles,Sport package,Sport...
# 3593                                       Alloy wheels
# 3595  Alloy wheels,Shift paddles,Ski bag,Sport packa...
#
#                                         safety_security  Gears  age  hp_kw  \
# 3587  Adaptive Cruise Control,Alarm system,Central d...    7.0  1.0  294.0
# 3590  ABS,Adaptive Cruise Control,Alarm system,Centr...    7.0  0.0  294.0
# 3592  ABS,Adaptive Cruise Control,Adaptive headlight...    7.0  1.0  294.0
# 3593  Adaptive Cruise Control,Alarm system,Central d...    7.0  1.0  294.0
# 3595  ABS,Adaptive Cruise Control,Adaptive headlight...    7.0  0.0  294.0
#
#      Type_ upholstery_type upholstery_color  displacement_cc  \
# 3587  Used           Cloth            Black           2480.0
# 3590  Used           Cloth            Black           2480.0
# 3592  Used    Full leather            Black           2480.0
# 3593  Used           Cloth            Black           2480.0
# 3595  Used    Part leather            Black           2480.0
#
#       Consumption_comb  Consumption_city  Consumption_country insp_new
# 3587               8.3               6.6                  6.6      Yes
# 3590               8.3               6.6                  6.6      Yes
# 3592               8.3               6.6                  6.6      Yes
# 3593               8.3               6.6                  6.6      Yes
# 3595               8.3               6.6                  6.6      Yes

# %%
pd.options.display.max_rows = 200
pd.options.display.max_columns = 200

# %%
df.loc[displacement_cc_index,["price","make_model","body_type","displacement_cc","age"]].sort_values(by = ["displacement_cc"])
# Out:
#          price      make_model      body_type  displacement_cc  age
# 12604  28990.0   Opel Insignia  Station wagon              1.0  0.0
# 12835  34925.0   Opel Insignia         Sedans              1.0  0.0
# 12467  37490.0   Opel Insignia  Station wagon              1.0  0.0
# 12473  34490.0   Opel Insignia  Station wagon              1.0  0.0
# 12484  33990.0   Opel Insignia         Sedans              1.0  0.0
# 12499  36990.0   Opel Insignia  Station wagon              1.0  0.0
# 12501  36990.0   Opel Insignia  Station wagon              1.0  0.0
# 12554  33590.0   Opel Insignia  Station wagon              1.0  0.0
# 12823  28500.0   Opel Insignia  Station wagon              1.0  0.0
# 12848  33990.0   Opel Insignia  Station wagon              1.0  0.0
# 12670  29990.0   Opel Insignia  Station wagon              1.0  0.0
# 12768  39190.0   Opel Insignia  Station wagon              1.0  0.0
# 12769  38990.0   Opel Insignia        Compact              1.0  0.0
# 12781  36500.0   Opel Insignia  Station wagon              1.0  0.0
# 12783  36490.0   Opel Insignia        Compact              1.0  0.0
# 12786  36780.0   Opel Insignia  Station wagon              1.0  0.0
# 12790  35990.0   Opel Insignia  Station wagon              1.0  0.0
# 12796  35990.0   Opel Insignia         Sedans              1.0  0.0
# 12798  33990.0   Opel Insignia  Station wagon              1.0  0.0
# 12750  41490.0   Opel Insignia         Sedans              1.0  0.0
# 12800  33790.0   Opel Insignia  Station wagon              1.0  0.0
# 12815  32990.0   Opel Insignia  Station wagon              1.0  0.0
# 14320   9999.0    Renault Clio         Sedans              1.0  1.0
# 14322   9999.0    Renault Clio         Sedans              1.0  1.0
# 14321   9999.0    Renault Clio         Sedans              1.0  1.0
# 14326   9999.0    Renault Clio         Sedans              1.0  1.0
# 14319   9999.0    Renault Clio         Sedans              1.0  1.0
# 14315   9999.0    Renault Clio         Sedans              1.0  1.0
# 14314   9999.0    Renault Clio         Sedans              1.0  1.0
# 14284   9999.0    Renault Clio         Sedans              1.0  1.0
# 14325   9999.0    Renault Clio         Sedans              1.0  1.0
# 13904   9490.0    Renault Clio         Sedans              1.0  2.0
# 14327   9999.0    Renault Clio         Sedans              1.0  1.0
# 12849  33990.0   Opel Insignia  Station wagon              1.0  0.0
# 14328   9999.0    Renault Clio         Sedans              1.0  1.0
# 14324   9999.0    Renault Clio         Sedans              1.0  1.0
# 10559  16950.0   Opel Insignia  Station wagon              2.0  3.0
# 14198   9680.0    Renault Clio         Sedans              2.0  2.0
# 13912   9400.0    Renault Clio         Sedans             54.0  2.0
# 10194  10940.0      Opel Corsa        Compact            122.0  0.0
# 7810   23940.0      Opel Astra         Sedans            139.0  0.0
# 7811   23940.0      Opel Astra         Sedans            139.0  0.0
# 7809   23940.0      Opel Astra         Sedans            139.0  0.0
# 7812   23940.0      Opel Astra         Sedans            139.0  0.0
# 8128   18830.0      Opel Astra  Station wagon            140.0  0.0
# 15574  31900.0  Renault Espace            Van            160.0  0.0
# 15575  31900.0  Renault Espace            Van            160.0  0.0
# 15576  31900.0  Renault Espace            Van            160.0  0.0
# 15577  31900.0  Renault Espace            Van            160.0  0.0
# 15579  31900.0  Renault Espace            Van            160.0  0.0
# 15578  31900.0  Renault Espace            Van            160.0  0.0
# 3603   52000.0         Audi A3         Sedans           2480.0  1.0
# 3590   62900.0         Audi A3         Sedans           2480.0  0.0
# 3592   56900.0         Audi A3         Sedans           2480.0  1.0
# 3593   58500.0         Audi A3         Sedans           2480.0  1.0
# 3595   63900.0         Audi A3  Station wagon           2480.0  0.0
# 3596   57400.0         Audi A3         Sedans           2480.0  1.0
# 3598   55000.0         Audi A3         Sedans           2480.0  2.0
# 3599   55000.0         Audi A3         Sedans           2480.0  1.0
# 3600   53000.0         Audi A3         Sedans           2480.0  1.0
# 3601   51900.0         Audi A3         Sedans           2480.0  2.0
# 3602   51900.0         Audi A3         Sedans           2480.0  1.0
# 3587   64900.0         Audi A3         Sedans           2480.0  1.0
# 3605   51999.0         Audi A3         Sedans           2480.0  2.0
# 3606   49900.0         Audi A3         Sedans           2480.0  1.0
# 3608   42500.0         Audi A3         Sedans           2480.0  3.0
# 3609   41000.0         Audi A3         Sedans           2480.0  3.0
# 3610   45890.0         Audi A3         Sedans           2480.0  1.0
# 3648   74600.0         Audi A3         Sedans           2480.0  1.0
# 3649   67600.0         Audi A3        Compact           2480.0  2.0
# 3604   50000.0         Audi A3         Sedans           2480.0  1.0
# 10771  12000.0   Opel Insignia  Station wagon           2967.0  3.0
# 7169   18490.0      Opel Astra  Station wagon          15898.0  1.0
# 10932  14300.0   Opel Insignia  Station wagon          16000.0  3.0

# %%
## opel insignia stagon vagon mesela 1.4 motormuş.     1.4 Motor == 1.400 cc

# %%
df[(df.make_model == "Opel Insignia") & (df.body_type=="Station wagon")][["displacement_cc","hp_kw", "Cylinders"]].sort_values(by="displacement_cc", ascending=False).head(50)
# Out:
#        displacement_cc  hp_kw  Cylinders
# 10932          16000.0   88.0        4.0
# 10771           2967.0  100.0        6.0
# 12519           2000.0  154.0        4.0
# 12503           2000.0  154.0        4.0
# 12494           2000.0  154.0        4.0
# 11929           2000.0  125.0        4.0
# 11800           2000.0  125.0        4.0
# 12959           2000.0  154.0        4.0
# 12469           2000.0  154.0        4.0
# 12464           2000.0  154.0        4.0
# 12761           2000.0  125.0        4.0
# 13054           2000.0  154.0        4.0
# 10556           2000.0  125.0        4.0
# 12170           2000.0  125.0        4.0
# 12179           2000.0  125.0        4.0
# 12414           2000.0  154.0        4.0
# 12945           2000.0  154.0        4.0
# 12938           2000.0  125.0        4.0
# 12412           2000.0  154.0        4.0
# 12411           2000.0  154.0        4.0
# 11870           2000.0  125.0        4.0
# 12518           2000.0  154.0        4.0
# 12470           2000.0  154.0        4.0
# 12520           2000.0  154.0        4.0
# 12521           2000.0  154.0        4.0
# 11988           2000.0  125.0        4.0
# 11977           2000.0  125.0        4.0
# 13050           2000.0  125.0        4.0
# 12560           2000.0  154.0        4.0
# 12526           2000.0  154.0        4.0
# 13029           2000.0  154.0        4.0
# 13027           2000.0  154.0        4.0
# 12265           2000.0  125.0        4.0
# 12529           1998.0  191.0        4.0
# 12496           1998.0  125.0        4.0
# 10571           1998.0  184.0        4.0
# 12488           1998.0  125.0        4.0
# 12575           1998.0  125.0        4.0
# 10548           1998.0  184.0        4.0
# 12654           1998.0  191.0        4.0
# 10507           1998.0  184.0        4.0
# 10484           1998.0  125.0        4.0
# 12773           1995.0  125.0        4.0
# 12024           1956.0  125.0        4.0
# 12182           1956.0  125.0        4.0
# 12183           1956.0  125.0        4.0
# 12195           1956.0  125.0        4.0
# 11224           1956.0  125.0        4.0
# 11318           1956.0  125.0        4.0
# 12175           1956.0  125.0        4.0

# %%
df[(df.make_model == "Opel Insignia") & (df.body_type=="Station wagon")].displacement_cc.describe()
# Out:
# count     1662.000000
# mean      1681.619735
# std        439.998790
# min          1.000000
# 25%       1524.500000
# 50%       1598.000000
# 75%       1956.000000
# max      16000.000000
# Name: displacement_cc, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15919 non-null  object
#  1   body_type            15919 non-null  object
#  2   price                15919 non-null  float64
#  3   km                   15919 non-null  float64
#  4   prev_owner           15919 non-null  float64
#  5   body_color           15919 non-null  object
#  6   paint_type           15919 non-null  object
#  7   number_of_doors      15919 non-null  float64
#  8   number_of_seats      15919 non-null  float64
#  9   gearing_type         15919 non-null  object
#  10  Cylinders            15919 non-null  float64
#  11  drive_chain          15919 non-null  object
#  12  Fuel                 15919 non-null  object
#  13  co2_emission         15919 non-null  float64
#  14  comfort_convenience  15919 non-null  object
#  15  entertainment_media  15919 non-null  object
#  16  Extras               15919 non-null  object
#  17  safety_security      15919 non-null  object
#  18  Gears                15919 non-null  float64
#  19  age                  15919 non-null  float64
#  20  hp_kw                15919 non-null  float64
#  21  Type_                15919 non-null  object
#  22  upholstery_type      15919 non-null  object
#  23  upholstery_color     15919 non-null  object
#  24  displacement_cc      15919 non-null  float64
#  25  Consumption_comb     15919 non-null  float64
#  26  Consumption_city     15919 non-null  float64
#  27  Consumption_country  15919 non-null  float64
#  28  insp_new             15919 non-null  object
# dtypes: float64(14), object(15)
# memory usage: 3.5+ MB

# %% [markdown]
# ### datayı temizlerken farkettiğimiz bazılarına müdahele ettiğimiz bazılarına ise dokunmadığımız değerleri düzeltelim:

# %%
df.loc[df["number_of_doors"]==1]
# Out:
#          make_model body_type   price       km  prev_owner body_color  \
# 13782  Renault Clio   Compact  8500.0  41493.0         1.0      White
#
#       paint_type  number_of_doors  number_of_seats gearing_type  Cylinders  \
# 13782   Metallic              1.0              5.0       Manual        4.0
#
#       drive_chain    Fuel  co2_emission  \
# 13782       front  Diesel          85.0
#
#                                      comfort_convenience  \
# 13782  Air conditioning,Cruise control,Hill Holder,Mu...
#
#                entertainment_media        Extras  \
# 13782  Bluetooth,On-board computer  Alloy wheels
#
#                                          safety_security  Gears  age  hp_kw  \
# 13782  ABS,Central door lock,Daytime running lights,D...    5.0  3.0   55.0
#
#       Type_ upholstery_type upholstery_color  displacement_cc  \
# 13782  Used           Cloth            Black           1461.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 13782               5.0               4.4                  4.4       No

# %%
df.loc[(df.make_model=="Renault Clio")&(df.body_type=="Compact"), "number_of_doors"].mode()[0]
# Out:
# 5.0

# %%
df.loc[df["number_of_doors"]==1] = df.loc[(df.make_model=="Renault Clio")&(df.body_type=="Compact"), "number_of_doors"].mode()[0]

# %%
df[df.number_of_doors==2]
# Out:
#        make_model body_type    price       km  prev_owner body_color  \
# 26        Audi A1   Compact  11444.0  84029.0         1.0       Blue
# 44        Audi A1    Sedans  11490.0  44120.0         1.0      Black
# 48        Audi A1   Compact  11490.0  58000.0         2.0      Black
# 55        Audi A1   Compact  10999.0  69500.0         1.0      Black
# 56        Audi A1   Compact  10900.0  43500.0         1.0      White
# ...           ...       ...      ...      ...         ...        ...
# 10304  Opel Corsa   Compact  10499.0    325.0         1.0        Red
# 10314  Opel Corsa   Compact   9990.0    100.0         1.0       Blue
# 10380  Opel Corsa   Compact  11290.0     12.0         1.0        Red
# 10413  Opel Corsa   Compact  11190.0     10.0         1.0       Blue
# 10444  Opel Corsa   Compact  10990.0     12.0         1.0       Blue
#
#       paint_type  number_of_doors  number_of_seats gearing_type  Cylinders  \
# 26      Metallic              2.0              4.0       Manual        3.0
# 44      Metallic              2.0              5.0       Manual        3.0
# 48      Metallic              2.0              4.0       Manual        3.0
# 55      Metallic              2.0              4.0       Manual        3.0
# 56      Metallic              2.0              4.0       Manual        3.0
# ...          ...              ...              ...          ...        ...
# 10304   Metallic              2.0              4.0       Manual        4.0
# 10314   Metallic              2.0              5.0       Manual        4.0
# 10380  Uni/basic              2.0              5.0       Manual        4.0
# 10413   Metallic              2.0              5.0       Manual        4.0
# 10444   Metallic              2.0              5.0       Manual        4.0
#
#       drive_chain     Fuel  co2_emission  \
# 26          front  Benzine          97.0
# 44          front   Diesel          94.0
# 48          front  Benzine         102.0
# 55          front  Benzine         102.0
# 56          front  Benzine          97.0
# ...           ...      ...           ...
# 10304       front  Benzine         126.0
# 10314       front  Benzine         126.0
# 10380       front  Benzine         126.0
# 10413       front  Benzine         126.0
# 10444       front  Benzine         126.0
#
#                                      comfort_convenience  \
# 26     Air conditioning,Automatic climate control,Ele...
# 44     Air conditioning,Cruise control,Electrical sid...
# 48     Air conditioning,Electrical side mirrors,Leath...
# 55     Air conditioning,Armrest,Automatic climate con...
# 56     Air conditioning,Electrical side mirrors,Power...
# ...                                                  ...
# 10304  Air conditioning,Electrical side mirrors,Power...
# 10314  Air conditioning,Electrical side mirrors,Hill ...
# 10380  Air conditioning,Electrical side mirrors,Power...
# 10413  Air conditioning,Electrical side mirrors,Hill ...
# 10444  Air conditioning,Electrical side mirrors,Power...
#
#                                      entertainment_media  \
# 26     Bluetooth,CD player,Hands-free equipment,MP3,O...
# 44     Bluetooth,Hands-free equipment,MP3,On-board co...
# 48                                   Bluetooth,CD player
# 55                                             CD player
# 56                     CD player,On-board computer,Radio
# ...                                                  ...
# 10304                                              Radio
# 10314  Bluetooth,CD player,Hands-free equipment,On-bo...
# 10380               Bluetooth,Hands-free equipment,Radio
# 10413                                 Radio,Sound system
# 10444               Bluetooth,Hands-free equipment,Radio
#
#                                           Extras  \
# 26                    Alloy wheels,Voice Control
# 44                                  Alloy wheels
# 48     Alloy wheels,Sport seats,Sport suspension
# 55                                  Alloy wheels
# 56                                  Alloy wheels
# ...                                          ...
# 10304                               Alloy wheels
# 10314                              Voice Control
# 10380                               Alloy wheels
# 10413                               Alloy wheels
# 10444                               Alloy wheels
#
#                                          safety_security  Gears  age  hp_kw  \
# 26     ABS,Central door lock,Daytime running lights,D...    5.0  3.0   70.0
# 44     ABS,Central door lock,Daytime running lights,D...    5.0  3.0   66.0
# 48     ABS,Central door lock,Daytime running lights,D...    5.0  3.0   60.0
# 55     ABS,Central door lock,Daytime running lights,D...    5.0  2.0   70.0
# 56     ABS,Central door lock,Daytime running lights,D...    5.0  3.0   60.0
# ...                                                  ...    ...  ...    ...
# 10304  ABS,Central door lock,Daytime running lights,D...    5.0  0.0   51.0
# 10314  ABS,Central door lock,Daytime running lights,D...    5.0  0.0   51.0
# 10380  ABS,Central door lock,Daytime running lights,D...    5.0  0.0   51.0
# 10413  ABS,Central door lock,Daytime running lights,D...    5.0  0.0   51.0
# 10444  ABS,Central door lock,Daytime running lights,D...    5.0  0.0   51.0
#
#                 Type_ upholstery_type upholstery_color  displacement_cc  \
# 26               Used           Cloth            Black            999.0
# 44               Used           Cloth            Black           1422.0
# 48               Used    Part leather            Black            999.0
# 55               Used           Cloth            Black            999.0
# 56               Used           Cloth            Black            999.0
# ...               ...             ...              ...              ...
# 10304             New           Cloth            Black           1229.0
# 10314             New           Cloth            Black           1229.0
# 10380  Pre-registered           Cloth            Black           1229.0
# 10413  Pre-registered           Cloth            Black           1229.0
# 10444  Pre-registered           Cloth            Black           1229.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 26                  4.2               3.7                  3.7      Yes
# 44                  3.6               3.3                  3.3       No
# 48                  4.4               3.9                  3.9      Yes
# 55                  4.4               3.9                  3.9       No
# 56                  4.2               3.7                  3.7       No
# ...                 ...               ...                  ...      ...
# 10304               5.4               4.6                  4.6      Yes
# 10314               5.4               4.6                  4.6      Yes
# 10380               5.4               4.6                  4.6      Yes
# 10413               5.4               4.6                  4.6      Yes
# 10444               5.4               4.6                  4.6      Yes
#
# [219 rows x 29 columns]

# %%
df.loc[df.number_of_doors==2,"make_model"].value_counts()
# Out:
# Audi A1       99
# Opel Corsa    93
# Audi A3       27
# Name: make_model, dtype: int64

# %%
df[df.number_of_doors==7]
# Out:
#            make_model body_type    price       km  prev_owner body_color  \
# 15202  Renault Espace       Van  21600.0  78000.0         1.0      Brown
#
#       paint_type  number_of_doors  number_of_seats gearing_type  Cylinders  \
# 15202   Metallic              7.0              5.0    Automatic        4.0
#
#       drive_chain    Fuel  co2_emission  \
# 15202       front  Diesel         120.0
#
#                                      comfort_convenience  \
# 15202  Air conditioning,Armrest,Automatic climate con...
#
#                                      entertainment_media  \
# 15202  Bluetooth,Digital radio,MP3,On-board computer,...
#
#                           Extras  \
# 15202  Alloy wheels,Touch screen
#
#                                          safety_security  Gears  age  hp_kw  \
# 15202  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  3.0  118.0
#
#       Type_ upholstery_type upholstery_color  displacement_cc  \
# 15202  Used    Full leather            Brown           1598.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 15202               4.6               4.4                  4.4       No

# %%
df.loc[(df.make_model=="Renault Espace")&(df.body_type=="Van"), "number_of_doors"].mode()[0]
# Out:
# 5.0

# %%
df.loc[df.number_of_doors==7,"number_of_doors"]
# Out:
# 15202    7.0
# Name: number_of_doors, dtype: float64

# %%
df.loc[df.number_of_doors==7,"number_of_doors"] = df.loc[(df.make_model=="Renault Espace")&(df.body_type=="Van"), "number_of_doors"].mode()[0]

# %%
df["number_of_doors"].value_counts()
# Out:
# 5.0    11789
# 4.0     3079
# 3.0      832
# 2.0      219
# Name: number_of_doors, dtype: int64

# %%
df["number_of_seats"].value_counts()
# Out:
# 5.0    14308
# 4.0     1127
# 7.0      362
# 2.0      119
# 6.0        2
# 3.0        1
# Name: number_of_seats, dtype: int64

# %%
df[df["number_of_seats"]==3]
# Out:
#      make_model body_type    price      km  prev_owner body_color paint_type  \
# 1636    Audi A1   Compact  23090.0  9821.0         1.0      Black   Metallic
#
#       number_of_doors  number_of_seats gearing_type  Cylinders drive_chain  \
# 1636              2.0              3.0    Automatic        4.0       front
#
#          Fuel  co2_emission  \
# 1636  Benzine         134.0
#
#                                     comfort_convenience  \
# 1636  Air conditioning,Armrest,Automatic climate con...
#
#                                     entertainment_media  \
# 1636  Bluetooth,CD player,Digital radio,Hands-free e...
#
#                                                  Extras  \
# 1636  Alloy wheels,Catalytic Converter,Sport package...
#
#                                         safety_security  Gears  age  hp_kw  \
# 1636  ABS,Central door lock,Daytime running lights,D...    7.0  1.0  141.0
#
#      Type_ upholstery_type upholstery_color  displacement_cc  \
# 1636  Used    Part leather            Black           1798.0
#
#       Consumption_comb  Consumption_city  Consumption_country insp_new
# 1636               5.8               4.9                  4.9      Yes

# %%
df[df["number_of_seats"]==6]
# Out:
#            make_model      body_type    price            km  prev_owner  \
# 582           Audi A1        Compact  13500.0  100000.00000         1.0
# 15890  Renault Espace  Station wagon  42490.0   23812.52433         1.0
#
#       body_color paint_type  number_of_doors  number_of_seats gearing_type  \
# 582        White   Metallic              5.0              6.0       Manual
# 15890      Black   Metallic              5.0              6.0    Automatic
#
#        Cylinders drive_chain     Fuel  co2_emission  \
# 582          4.0       front  Benzine         105.0
# 15890        4.0       front   Diesel         168.0
#
#                                      comfort_convenience  \
# 582                                     Air conditioning
# 15890  Air conditioning,Armrest,Automatic climate con...
#
#                                      entertainment_media  \
# 582                                    On-board computer
# 15890  Bluetooth,Hands-free equipment,On-board comput...
#
#                           Extras  \
# 582                 Alloy wheels
# 15890  Alloy wheels,Touch screen
#
#                                          safety_security  Gears  age  hp_kw  \
# 582                                                  ABS    5.0  2.0   70.0
# 15890  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  1.0  147.0
#
#       Type_ upholstery_type upholstery_color  displacement_cc  \
# 582    Used           Cloth            Black           1000.0
# 15890   New           Cloth            Other           1997.0
#
#        Consumption_comb  Consumption_city  Consumption_country insp_new
# 582                 4.4               3.9                  3.9       No
# 15890               5.7               5.3                  5.3      Yes

# %%
# ?????
